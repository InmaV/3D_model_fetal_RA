# %%
import numpy as np, scipy, pyvista
from tqdm.notebook import tqdm
import struct
import matplotlib.pyplot as plt
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
def solveLaplaceBeltrami2(points, triangles, boundary, move_together):
    """
    Solve laplace-beltrami equation with boundary conditions 
    """
    nPoints = len(points)
    nConstraints = len(boundary)
    L = ComputeCotangentLaplacian(points.T, triangles.T)
    
    lagrange_boundary = np.zeros((len(boundary), nPoints))
    boundary_values = np.zeros(nConstraints)
    for i, (k, v) in enumerate(boundary.items()):  
        lagrange_boundary[i, k] = 1
        boundary_values[i] = v
    
    constraints = []
    for structure in move_together:
        ref = structure[0]
        for idx in structure[1:]:
            row = np.zeros(nPoints)
            row[idx] = 1
            row[ref] = -1
            constraints.append(row)
    lagrange_together = np.array(constraints) 
    together_values = np.zeros(len(constraints)) #s_i - s_ref = 0
    
    lagrange_multipliers = np.vstack([lagrange_boundary, lagrange_together])
    rhs_values = np.concatenate([boundary_values, together_values])

    zeros = np.zeros((lagrange_multipliers.shape[0], lagrange_multipliers.shape[0]))
    L_hat = scipy.sparse.bmat([[L, lagrange_multipliers.T],[lagrange_multipliers, zeros]]).tocsr()
    b_hat = np.concatenate([np.zeros(nPoints), rhs_values])
    x_hat = scipy.sparse.linalg.spsolve(L_hat, b_hat)
    return x_hat[:nPoints]

def solveLaplaceBeltrami(points, triangles, boundary):
    """
    Solve laplace-beltrami equation with boundary conditions 
    """
    nPoints = len(points)
    nConstraints = len(boundary)
    L = ComputeCotangentLaplacian( points.T, triangles.T)
    lagrange_multipliers = np.zeros((len(boundary), nPoints))
    boundary_values = np.zeros(nConstraints)
    for i, (k, v) in enumerate(boundary.items()):  
        lagrange_multipliers[i, k] = 1
        boundary_values[i] = v
    zeros = np.zeros((nConstraints, nConstraints))
    L_hat = scipy.sparse.bmat([[L, lagrange_multipliers.T], [lagrange_multipliers, zeros]]).tocsr()
    b_hat = np.concatenate([np.zeros(nPoints), boundary_values])
    print(np.shape(L_hat))
    print(np.shape(b_hat))
    x_hat = scipy.sparse.linalg.spsolve(L_hat, b_hat)
    return x_hat[:nPoints]


def ComputeCotangentLaplacian(vertex, faces):
    """
    Calculates the laplacian of a mesh
    vertex 3xN numpy.array: vertices
    faces 3xM numpy.array: faces
    Return the Laplacian (sparse matrix probably).
    """
    n = vertex.shape[1]
    m = faces.shape[1]
    
    #compute mesh weight matrix
    W = scipy.sparse.coo_matrix((n,n))
    for i in np.arange(1,4,1):
        i1 = np.mod(i-1,3)
        i2 = np.mod(i  ,3)
        i3 = np.mod(i+1,3)
        pp = vertex[:,faces[i2,:]] - vertex[:,faces[i1,:]]
        qq = vertex[:,faces[i3,:]] - vertex[:,faces[i1,:]]
        #% normalize the vectors
        pp = pp / np.sqrt(np.sum(pp**2, axis=0))
        qq = qq / np.sqrt(np.sum(qq**2, axis=0))

        #% compute angles
        ang = np.arccos(np.sum(pp*qq, axis=0))
        W = W + scipy.sparse.coo_matrix( (1 / np.tan(ang),(faces[i2,:],faces[i3,:])), shape=(n, n) )
        W = W + scipy.sparse.coo_matrix( (1 / np.tan(ang),(faces[i3,:],faces[i2,:])), shape=(n, n) )

    W = W.tocsr()

    #compute laplacian
    d = W.sum(axis=0)
    D = scipy.sparse.dia_matrix((d, 0), shape=(n,n) )
    L = D - W

    return L

# %%
mesh = pyvista.PolyData('reference.vtk')
mesh.point_data['originalPointIdxMesh'] = np.arange(mesh.n_points) # So later I can get the points
surface = mesh.extract_surface()
triangles = surface.faces.reshape((-1, 4))[:, 1:]

boundary = {}
tricuspid_idx = np.where(mesh.point_data['tricuspid_valve'] == 1)[0]
no_movement_idx = np.where(mesh.point_data['wall'] == 1)[0] # Avoid repeated points 
RA_idx = np.where(mesh.point_data['RA'] == 1)[0]
IVC_idx = np.where(mesh.point_data['IVC'] == 1)[0]
SVC_idx = np.where(mesh.point_data['SVC'] == 1)[0]
FO_idx = np.where(mesh.point_data['FO'] == 1)[0]
eustachian_valve_idx = np.where(np.logical_and(mesh.point_data['eustachian_valve'] == 1,
                                               mesh.point_data['IVC'] == 0))[0] # Avoid repeated points
move_together = [IVC_idx,SVC_idx,FO_idx,eustachian_valve_idx]

for i in tricuspid_idx:
    boundary[i] = 1.0
for i in no_movement_idx:
    boundary[i] = 0.0

z = solveLaplaceBeltrami2(mesh.points.copy(), triangles, boundary, move_together)

# %%
# Put it back in the original order
z_mesh = np.zeros((mesh.n_points, 1))
z_mesh[mesh.point_data['originalPointIdxMesh']] = z.reshape(surface.points.shape[0], 1)
z_mesh = z_mesh**1.5
mesh.point_data['z'] = z_mesh.flatten()
mesh.save('test_mesh.vtk')

# %%
plt.hist(z_mesh)
plt.show()

# %%
def volume_error3(variable,target_volume,mesh,z_mesh,e_2,no_movement_volume,RA_idx,original_mesh):
    s_try = variable
    temp = mesh.copy()
    temp.points = original_mesh.points + s_try * z_mesh * e_2 # z_mesh: vector with heat pattern
    
    
    RA_points = temp.points[RA_idx]
    center_RA = RA_points.mean(axis=0) # RA centre

    vectors = temp.points - center_RA  
    distances = np.linalg.norm(vectors, axis=1, keepdims=True)

    radial_unit_vectors = vectors / distances # normalize: (-1, 1)

    displacement = radial_unit_vectors # displacememt as a function of distance to centre

    temp.points += -0.4 * s_try * displacement # radial movement: 40% of longitudinal movement
    
    
    vol = (temp.volume-no_movement_volume)/1000
    return (vol - target_volume)**2

# %%
import numpy as np
import struct
from scipy.optimize import minimize
from scipy.optimize import minimize_scalar
from tqdm import tqdm

data = np.load(f"RA_volume.npz") # volume in a cycle (0D model) 
V_interp_orig = np.concatenate((data['data'],data['data'],data['data'],data['data'],data['data'],[data['data'][0]])) #+ 0.3295877566276872
V_interp = V_interp_orig
#_orig
#V_interp = np.roll(V_interp_orig, -165)

N_steps = 4301
tol = 1
tv = []
volumes = []
diameters = []
lengths = []
depths = []
V_cav = []
stretch = []

mesh = pyvista.PolyData('./Meshes/RA_test_mesh.vtk')
mesh_RA = pyvista.PolyData('./Meshes/Inma_funciona_final3_RA.stl')
no_movement_volume = mesh.volume - mesh_RA.volume/1000 # per calcular volum del RA, sempre restarem el volum dels vessels 
original_mesh = pyvista.PolyData('./Meshes/RA_test_mesh.vtk')

with open('./Meshes/RA_data_bin.dat', 'wb') as f:
    f.write(struct.pack(f'<{2}i', mesh.n_points, N_steps))
    for i in range(mesh.n_points):
        f.write(struct.pack(f'<{3}d', i+1,i+1,i+1))
    e_2 = np.array([0, 1, 0]).reshape((1, 3)) # la meva vàlvula és a l'eix y
    
    for t in tqdm(range(N_steps)):
        target_volume = V_interp[t] 

        result = minimize_scalar(
            volume_error3,
            args=(target_volume, mesh, z_mesh, e_2, no_movement_volume, RA_idx, original_mesh),
            tol=1e-3,
            bounds=(-5, 15),
            method='bounded')

        s = result.x      # quantitat de moviment 
        stretch.append(s)  

        # Aplicamos la deformación a la malla
        mesh.points = original_mesh.points + s * z_mesh * e_2
        
        RA_points = mesh.points[RA_idx]
        center_RA = RA_points.mean(axis=0)

        vectors = mesh.points - center_RA  
        distances = np.linalg.norm(vectors, axis=1, keepdims=True)

        radial_unit_vectors = vectors / distances # normalize: (-1, 1)

        displacement = radial_unit_vectors

        mesh.points += -0.4 * s * displacement
        RA_points = mesh.points[RA_idx]

        volumes.append((mesh.volume-no_movement_volume)/1000)
        tv.append(np.min(RA_points[:, 1])/10)
        diameters.append((np.max(RA_points[:, 0])-np.min(RA_points[:, 0]))/10)
        lengths.append((np.max(RA_points[:, 1])-np.min(RA_points[:, 1]))/10)
        depths.append((np.max(RA_points[:, 2])-np.min(RA_points[:, 2]))/10)
        V_cav.append(target_volume)

        # Guardar archivo .vtk
        new_mesh = mesh.copy()
        new_mesh.points /= 1000
        new_mesh.save(f'./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_{t}.vtk') #+164

        # Guardar puntos deformados
        new_mesh.points.tofile(f, format='d')

# Plot dels resultats
fig, ax1 = plt.subplots()

ax1.plot(volumes, color='blue')
ax1.plot(V_cav, color='green', linestyle='--')
ax1.set_ylabel('Volume (ml)', color='black')
ax1.tick_params(axis='y', labelcolor='black')

fig.tight_layout()
plt.show()

fig, ax1 = plt.subplots()

ax1.plot(lengths, color='blue')
ax1.set_ylabel('Length (cm)', color='black')
ax1.tick_params(axis='y', labelcolor='black')

fig.tight_layout()
plt.show()

print(f"Change in length = {np.round(np.min(lengths),2)}/{np.round(np.max(lengths),2)} = {np.round(np.min(lengths)/np.max(lengths),2)}")
print(f"Change in diameter = {np.round(np.min(diameters),2)}/{np.round(np.max(diameters),2)} = {np.round(np.min(diameters)/np.max(diameters),2)}")
print(f"Change in depth = {np.round(np.min(depths),2)}/{np.round(np.max(depths),2)} = {np.round(np.min(depths)/np.max(depths),2)}")

print(f"Real change in length (patient MR175667 date 20250508) = 0.68")
print(f"Real change in diameter (patient MR175667 date 20250508) = 0.80")
# Out:
#   0%|                                                  | 0/4301 [00:00<?, ?it/s]/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minimize.py:892: RuntimeWarning: Method 'bounded' does not support relative tolerance in x; defaulting to absolute tolerance.
#   warn("Method 'bounded' does not support relative tolerance in x; "
# 100%|███████████████████████████████████████| 4301/4301 [05:37<00:00, 12.76it/s]
# Change in length = 1.38/1.97 = 0.7
# Change in diameter = 1.52/1.79 = 0.85
# Change in depth = 1.52/1.79 = 0.85
# Real change in length (patient MR175667 date 20250508) = 0.68
# Real change in diameter (patient MR175667 date 20250508) = 0.80

# %%
import pyvista as pv
import numpy as np
import glob
import re
import os

# Buscar todos los archivos .vtk en la carpeta
vtk_files = glob.glob("./Meshes/RA_TT2_deformed_more2/*.vtk")
def extract_number(filename):
    # Busca el número ANTES del .vtk, por ejemplo "RA_test_deformed_23.vtk" → 23
    match = re.search(r'(\d+)(?=\.vtk$)', os.path.basename(filename))
    return int(match.group(1)) if match else -1

for old_path in vtk_files:

    old_number = extract_number(old_path)

    # Solo modificar archivos >= 2151
    if old_number >= 2151:

        new_number = old_number - 2151

        # Construir nuevo nombre
        new_filename = re.sub(
            r'(\d+)(?=\.vtk$)',
            str(new_number),
            os.path.basename(old_path)
        )

        new_path = os.path.join(
            os.path.dirname(old_path),
            new_filename
        )

        print(f"{os.path.basename(old_path)} -> {new_filename}")

        os.rename(old_path, new_path)

# %%
import os
import pyvista as pv

# Carpeta donde tienes los archivos .vtk
input_folder = "/Users/inmav/Desktop/Inma/IDIBAPS/Artificial_Placenta/3D_model/Meshes/RA_TT2_deformed_1e-4/"

# Carpeta donde se guardarán los archivos .stl
output_folder = "/Users/inmav/Desktop/Inma/IDIBAPS/Artificial_Placenta/3D_model/Meshes/RA_TT2_deformed_1e-4_stl/"

# Crear la carpeta de salida si no existe
os.makedirs(output_folder, exist_ok=True)

# Recorrer todos los archivos de la carpeta de entrada
for filename in os.listdir(input_folder):
    if filename.endswith(".vtk"):
        vtk_path = os.path.join(input_folder, filename)
        
        # Leer el archivo .vtk
        mesh = pv.read(vtk_path)
        
        # Nombre de salida cambiando la extensión a .stl
        stl_filename = os.path.splitext(filename)[0] + ".stl"
        stl_path = os.path.join(output_folder, stl_filename)
        
        # Guardar como STL
        mesh.save(stl_path)

print("¡Conversión completada!")
# Out:
# ¡Conversión completada!

# %%
import pyvista as pv
import numpy as np
import glob
import re
import os

# Buscar todos los archivos .vtk en la carpeta
vtk_files = glob.glob("./Meshes/RA_TT2_deformed_5e-4/*.vtk")

def extract_number(filename):
    # Busca el número ANTES del .vtk, por ejemplo "RA_test_deformed_23.vtk" → 23
    match = re.search(r'(\d+)(?=\.vtk$)', os.path.basename(filename))
    return int(match.group(1)) if match else -1

# Ordenar los archivos de forma numérica ascendente
vtk_files.sort(key=extract_number)
areas = []
volumes = []

# Leer las mallas
all_points = []
for file in vtk_files:
    mesh = pv.read(file)
    print(file)
    all_points.append(mesh.points.flatten())
    submesh = None
    if "tricuspid_valve" in mesh.array_names:
        mask = mesh["tricuspid_valve"] > 0  
        submesh = mesh.extract_points(mask)

    areas.append(submesh.area/1e-4)
    volumes.append(mesh.volume)

n_points = mesh.points.shape[0]

indices = np.arange(1, n_points + 1)
header = np.repeat(indices, 3)




# Guardar en archivo .dat
with open("dynamicmesh_inma_5e-4.dat", "w") as f:
    # Primera fila: número de archivos VTK
    f.write(f"{len(vtk_files)}\n")
    # Segunda fila: n_points * 3
    f.write(f"{n_points*3}\n")
    # Fila de índices
    np.savetxt(f, header.reshape(1, -1), fmt="%d", delimiter="\t")
    # Coordenadas
    np.savetxt(f, all_points, fmt="%.6f", delimiter="\t")
# Out:
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_0.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_1.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_2.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_3.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_5.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_6.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_7.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_8.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_9.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_10.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_11.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_12.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_13.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_14.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_15.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_16.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_17.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_18.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_19.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_20.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_21.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_22.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_23.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_24.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_25.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_26.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_27.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_28.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_29.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_30.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_31.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_32.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_33.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_34.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_35.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_36.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_37.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_38.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_39.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_40.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_41.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_42.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_43.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_44.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_45.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_46.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_47.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_48.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_49.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_50.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_51.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_52.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_53.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_54.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_55.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_56.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_57.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_58.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_59.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_60.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_61.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_62.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_63.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_64.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_65.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_66.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_67.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_68.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_69.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_70.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_71.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_72.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_73.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_74.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_75.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_76.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_77.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_78.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_79.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_80.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_81.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_82.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_83.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_84.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_85.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_86.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_87.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_88.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_89.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_90.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_91.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_92.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_93.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_94.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_95.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_96.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_97.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_98.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_99.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_100.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_101.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_102.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_103.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_104.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_105.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_106.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_107.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_108.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_109.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_110.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_111.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_112.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_113.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_114.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_115.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_116.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_117.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_118.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_119.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_120.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_121.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_122.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_123.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_124.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_125.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_126.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_127.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_128.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_129.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_130.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_131.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_132.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_133.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_134.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_135.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_136.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_137.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_138.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_139.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_140.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_141.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_142.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_143.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_144.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_145.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_146.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_147.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_148.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_149.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_150.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_151.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_152.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_153.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_154.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_155.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_156.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_157.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_158.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_159.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_160.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_161.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_162.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_163.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_164.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_165.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_166.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_167.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_168.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_169.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_170.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_171.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_172.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_173.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_174.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_175.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_176.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_177.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_178.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_179.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_180.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_181.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_182.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_183.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_184.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_185.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_186.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_187.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_188.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_189.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_190.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_191.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_192.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_193.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_194.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_195.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_196.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_197.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_198.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_199.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_200.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_201.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_202.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_203.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_204.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_205.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_206.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_207.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_208.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_209.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_210.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_211.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_212.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_213.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_214.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_215.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_216.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_217.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_218.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_219.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_220.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_221.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_222.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_223.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_224.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_225.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_226.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_227.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_228.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_229.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_230.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_231.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_232.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_233.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_234.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_235.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_236.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_237.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_238.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_239.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_240.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_241.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_242.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_243.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_244.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_245.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_246.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_247.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_248.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_249.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_250.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_251.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_252.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_253.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_254.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_255.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_256.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_257.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_258.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_259.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_260.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_261.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_262.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_263.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_264.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_265.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_266.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_267.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_268.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_269.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_270.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_271.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_272.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_273.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_274.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_275.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_276.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_277.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_278.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_279.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_280.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_281.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_282.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_283.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_284.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_285.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_286.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_287.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_288.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_289.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_290.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_291.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_292.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_293.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_294.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_295.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_296.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_297.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_298.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_299.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_300.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_301.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_302.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_303.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_304.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_305.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_306.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_307.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_308.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_309.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_310.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_311.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_312.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_313.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_314.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_315.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_316.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_317.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_318.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_319.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_320.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_321.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_322.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_323.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_324.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_325.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_326.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_327.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_328.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_329.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_330.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_331.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_332.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_333.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_334.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_335.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_336.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_337.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_338.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_339.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_340.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_341.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_342.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_343.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_344.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_345.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_346.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_347.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_348.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_349.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_350.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_351.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_352.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_353.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_354.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_355.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_356.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_357.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_358.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_359.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_360.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_361.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_362.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_363.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_364.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_365.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_366.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_367.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_368.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_369.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_370.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_371.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_372.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_373.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_374.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_375.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_376.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_377.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_378.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_379.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_380.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_381.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_382.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_383.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_384.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_385.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_386.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_387.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_388.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_389.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_390.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_391.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_392.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_393.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_394.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_395.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_396.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_397.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_398.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_399.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_400.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_401.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_402.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_403.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_404.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_405.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_406.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_407.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_408.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_409.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_410.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_411.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_412.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_413.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_414.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_415.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_416.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_417.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_418.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_419.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_420.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_421.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_422.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_423.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_424.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_425.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_426.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_427.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_428.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_429.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_430.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_431.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_432.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_433.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_434.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_435.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_436.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_437.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_438.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_439.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_440.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_441.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_442.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_443.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_444.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_445.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_446.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_447.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_448.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_449.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_450.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_451.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_452.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_453.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_454.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_455.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_456.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_457.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_458.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_459.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_460.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_461.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_462.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_463.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_464.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_465.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_466.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_467.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_468.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_469.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_470.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_471.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_472.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_473.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_474.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_475.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_476.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_477.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_478.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_479.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_480.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_481.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_482.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_483.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_484.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_485.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_486.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_487.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_488.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_489.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_490.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_491.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_492.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_493.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_494.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_495.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_496.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_497.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_498.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_499.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_500.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_501.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_502.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_503.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_504.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_505.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_506.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_507.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_508.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_509.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_510.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_511.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_512.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_513.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_514.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_515.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_516.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_517.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_518.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_519.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_520.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_521.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_522.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_523.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_524.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_525.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_526.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_527.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_528.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_529.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_530.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_531.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_532.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_533.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_534.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_535.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_536.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_537.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_538.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_539.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_540.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_541.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_542.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_543.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_544.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_545.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_546.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_547.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_548.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_549.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_550.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_551.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_552.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_553.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_554.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_555.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_556.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_557.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_558.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_559.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_560.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_561.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_562.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_563.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_564.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_565.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_566.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_567.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_568.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_569.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_570.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_571.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_572.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_573.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_574.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_575.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_576.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_577.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_578.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_579.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_580.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_581.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_582.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_583.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_584.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_585.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_586.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_587.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_588.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_589.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_590.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_591.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_592.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_593.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_594.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_595.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_596.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_597.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_598.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_599.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_600.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_601.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_602.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_603.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_604.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_605.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_606.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_607.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_608.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_609.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_610.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_611.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_612.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_613.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_614.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_615.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_616.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_617.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_618.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_619.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_620.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_621.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_622.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_623.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_624.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_625.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_626.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_627.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_628.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_629.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_630.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_631.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_632.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_633.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_634.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_635.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_636.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_637.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_638.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_639.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_640.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_641.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_642.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_643.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_644.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_645.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_646.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_647.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_648.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_649.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_650.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_651.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_652.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_653.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_654.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_655.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_656.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_657.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_658.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_659.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_660.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_661.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_662.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_663.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_664.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_665.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_666.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_667.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_668.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_669.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_670.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_671.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_672.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_673.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_674.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_675.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_676.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_677.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_678.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_679.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_680.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_681.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_682.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_683.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_684.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_685.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_686.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_687.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_688.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_689.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_690.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_691.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_692.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_693.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_694.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_695.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_696.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_697.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_698.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_699.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_700.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_701.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_702.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_703.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_704.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_705.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_706.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_707.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_708.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_709.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_710.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_711.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_712.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_713.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_714.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_715.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_716.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_717.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_718.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_719.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_720.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_721.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_722.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_723.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_724.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_725.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_726.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_727.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_728.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_729.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_730.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_731.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_732.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_733.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_734.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_735.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_736.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_737.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_738.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_739.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_740.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_741.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_742.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_743.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_744.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_745.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_746.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_747.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_748.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_749.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_750.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_751.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_752.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_753.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_754.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_755.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_756.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_757.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_758.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_759.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_760.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_761.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_762.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_763.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_764.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_765.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_766.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_767.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_768.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_769.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_770.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_771.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_772.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_773.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_774.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_775.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_776.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_777.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_778.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_779.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_780.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_781.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_782.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_783.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_784.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_785.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_786.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_787.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_788.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_789.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_790.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_791.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_792.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_793.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_794.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_795.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_796.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_797.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_798.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_799.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_800.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_801.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_802.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_803.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_804.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_805.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_806.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_807.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_808.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_809.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_810.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_811.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_812.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_813.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_814.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_815.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_816.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_817.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_818.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_819.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_820.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_821.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_822.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_823.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_824.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_825.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_826.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_827.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_828.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_829.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_830.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_831.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_832.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_833.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_834.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_835.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_836.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_837.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_838.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_839.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_840.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_841.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_842.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_843.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_844.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_845.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_846.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_847.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_848.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_849.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_850.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_851.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_852.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_853.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_854.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_855.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_856.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_857.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_858.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_859.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_860.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_861.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_862.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_863.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_864.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_865.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_866.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_867.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_868.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_869.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_870.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_871.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_872.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_873.vtk
# ...
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4016.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4017.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4018.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4019.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4020.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4021.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4022.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4023.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4024.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4025.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4026.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4027.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4028.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4029.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4030.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4031.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4032.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4033.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4034.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4035.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4036.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4037.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4038.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4039.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4040.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4041.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4042.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4043.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4044.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4045.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4046.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4047.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4048.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4049.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4050.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4051.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4052.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4053.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4054.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4055.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4056.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4057.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4058.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4059.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4060.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4061.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4062.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4063.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4064.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4065.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4066.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4067.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4068.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4069.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4070.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4071.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4072.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4073.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4074.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4075.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4076.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4077.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4078.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4079.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4080.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4081.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4082.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4083.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4084.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4085.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4086.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4087.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4088.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4089.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4090.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4091.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4092.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4093.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4094.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4095.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4096.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4097.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4098.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4099.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4100.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4101.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4102.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4103.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4104.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4105.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4106.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4107.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4108.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4109.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4110.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4111.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4112.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4113.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4114.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4115.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4116.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4117.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4118.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4119.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4120.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4121.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4122.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4123.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4124.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4125.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4126.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4127.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4128.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4129.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4130.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4131.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4132.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4133.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4134.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4135.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4136.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4137.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4138.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4139.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4140.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4141.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4142.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4143.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4144.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4145.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4146.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4147.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4148.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4149.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4150.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4151.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4152.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4153.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4154.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4155.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4156.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4157.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4158.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4159.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4160.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4161.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4162.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4163.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4164.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4165.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4166.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4167.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4168.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4169.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4170.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4171.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4172.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4173.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4174.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4175.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4176.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4177.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4178.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4179.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4180.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4181.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4182.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4183.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4184.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4185.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4186.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4187.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4188.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4189.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4190.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4191.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4192.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4193.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4194.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4195.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4196.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4197.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4198.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4199.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4200.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4201.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4202.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4203.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4204.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4205.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4206.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4207.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4208.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4209.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4210.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4211.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4212.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4213.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4214.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4215.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4216.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4217.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4218.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4219.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4220.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4221.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4222.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4223.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4224.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4225.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4226.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4227.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4228.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4229.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4230.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4231.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4232.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4233.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4234.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4235.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4236.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4237.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4238.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4239.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4240.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4241.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4242.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4243.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4244.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4245.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4246.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4247.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4248.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4249.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4250.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4251.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4252.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4253.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4254.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4255.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4256.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4257.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4258.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4259.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4260.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4261.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4262.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4263.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4264.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4265.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4266.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4267.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4268.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4269.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4270.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4271.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4272.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4273.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4274.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4275.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4276.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4277.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4278.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4279.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4280.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4281.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4282.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4283.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4284.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4285.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4286.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4287.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4288.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4289.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4290.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4291.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4292.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4293.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4294.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4295.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4296.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4297.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4298.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4299.vtk
# ./Meshes/RA_TT2_deformed_5e-4/RA_test_deformed_4300.vtk

# %%
plt.plot(volumes)
print(n_points*3) # 103890
# Out:
# 66900

# %%
fig, ax1 = plt.subplots()

ax1.plot(stretch, color='blue')
ax1.set_ylabel('Variable s', color='black')
ax1.tick_params(axis='y', labelcolor='black')

fig.tight_layout()
plt.show()
